# %% [markdown]
# <a href="https://colab.research.google.com/github/aceholland/Cprogramming_college3rdsem/blob/main/Cprograms_2ndyearcollege.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **Basic**

# %% [markdown]
# 1. Write a C program to check whether a year is a leap year.

# %%
# %%writefile leap.c
# #include <stdio.h>
#
# int main() {
#     int year;
#
#     printf("Enter a year: ");
#     scanf("%d", &year);
#
#     if (year % 400 == 0 || (year % 4 == 0 && year % 100 != 0)) {
#         printf("%d is a leap year.", year);
#     } else {
#         printf("%d is not a leap year.", year);
#     }
#
#     return 0;
# }
# Out:
# Overwriting leap.c

# %%
# !gcc leap.c -o leap
# !./leap
# Out:
# Enter a year: 2007
# 2007 is not a leap year.

# %% [markdown]
# 2. Write a C program to check whether a number is positive, negative, or zero.

# %%
# %%writefile positive.c
# #include <stdio.h>
# int main(){
#   int number;
#   printf("Enter a number :");
#   scanf("%d", &number);
#   if (number>0){
#     printf("Its positive");
#   }
#  else if (number<0){
#   printf("Its negative");
#  }
#  else{
#   printf("Its 0");
#  }
#  return 0;
# }
# Out:
# Overwriting positive.c

# %%
# !gcc positive.c -o positive
# !./positive
# Out:
# Enter a number :9
# Its positive

# %% [markdown]
# 3. Write a C program to check whether a character is a vowel or consonant

# %%
# %%writefile character.c
# #include<stdio.h>
# int main(){
#   char c;
#   printf("Enter a character");
#   scanf("%c", &c);
#   if (c=='a' || c=='e' || c=='i' || c=='o' || c=='u' || c=='A' || c=='E' ||c=='I' || c=='O' || c=='U'){
#     printf("Its a vowel");
#   }
#   else {
#     printf("Its a consonant");
#   }
#   return 0;
# }
# Out:
# Writing character.c

# %%
# !gcc character.c -o character
# !./character
# Out:
# Enter a characterb
# Its a consonant

# %% [markdown]
# 4. Write a C program to check whether a person is eligible to vote based on age.
#
# I will use ternary operator.

# %%
# %%writefile age.c
# #include<stdio.h>
# int main(){
#   int age;
#   printf("enter the age: ");
#   scanf("%d", &age);
#   (age>=18)? printf("Eligible to vote") : printf("Not eligible to vote");
#   return 0;
# }
# Out:
# Overwriting age.c

# %%
# !gcc age.c -o age
# !./age
# Out:
# enter the age: 89
# Eligible to vote

# %% [markdown]
# 5. Write a C program to find the greater of two numbers.

# %%
# %%writefile number.c
# #include <stdio.h>
# int main(){
#   int a, b;
#   printf("Enter first number: ");
#   scanf("%d", &a);
#   printf("Enter second number: ");
#   scanf("%d", &b);
#   (a>b)? printf("The greater number is %d", a): printf("The greater number is %d", b);
#   return 0;
# }
# Out:
# Writing number.c

# %%
# !gcc number.c -o number
# !./number
# Out:
# Enter first number: 8
# Enter second number: 940586
# The greater number is 940586

# %% [markdown]
# 6. Write a C program to check whether a number is even or odd.

# %%
# %%writefile even.c
# #include <stdio.h>
# int main(){
#   int a;
#   printf("Enter the number: ");
#   scanf("%d", &a);
#   (a%2==0)?printf(" %d is an even number", a): printf( "%d is an odd number", a);
#   return 0;
# }
# Out:
# Writing even.c

# %%
# !gcc even.c -o even
# !./even
# Out:
# Enter the number: 84759480
#  84759480 is an even number

# %% [markdown]
# # **Intermediate**

# %% [markdown]
# 7. Write a C program to find the greatest of three numbers.

# %%
# %%writefile greatest.c
# #include<stdio.h>
# int main(){
#   int a, b, c;
#   printf("Enter a: ");
#   scanf("%d", &a);
#   printf("Enter b: ");
#   scanf("%d", &b);
#   printf("Enter c: ");
#   scanf("%d", &c);
#
#   if (a>b & a>c){
#     printf("%d is greatest", a);
#     if (b>c){
#         printf("%d is greater", b);
#       }
#       else{
#         printf("%d is smallest", c);
#       }
#     }
#   else if (b>a && b>c){
#     printf("%d is greatest", b);
#     if (a>c){
#        printf("%d is greater", a);
#     }
#     else{
#        printf("%d is greater", c);
#     }
#   }
#   else {
#     if (a>b){
#     printf("%d is greater",a );
#   }
#     else{
#       printf("%d is greater", b);
#     }
#   }
#     return 0;
# }
# Out:
# Overwriting greatest.c

# %%
# !gcc greatest.c -o greatest
# !./greatest
# Out:
# Enter a: 8
# Enter b: 90
# Enter c: 4
# 90 is greatest8 is greater

# %% [markdown]
# Less lenghty

# %%
# %%writefile greatest2.c
# #include <stdio.h>
#
# int main() {
#     int a, b, c;
#
#     printf("Enter a, b and c: ");
#     scanf("%d %d %d", &a, &b, &c);
#
#     if (a == b && b == c) {
#     printf("All numbers are equal");
# }
# else if (a == b) {
#     printf("a and b are equal");
# }
# else if (a == c) {
#     printf("a and c are equal");
# }
# else if (b == c) {
#     printf("b and c are equal");
# }
# else {
#
#
#     if (a > b && a > c) {
#         printf("%d is greatest\n", a);
#         if (b > c)
#             printf("%d is greater\n%d is smallest", b, c);
#         else
#             printf("%d is greater\n%d is smallest", c, b);
#     }
#     else if (b > a && b > c) {
#         printf("%d is greatest\n", b);
#         if (a > c)
#             printf("%d is greater\n%d is smallest", a, c);
#         else
#             printf("%d is greater\n%d is smallest", c, a);
#     }
#     else {
#         printf("%d is greatest\n", c);
#         if (a > b)
#             printf("%d is greater\n%d is smallest", a, b);
#         else
#             printf("%d is greater\n%d is smallest", b, a);
#     }
# }
#     return 0;
# }
# Out:
# Overwriting greatest2.c

# %%
# !gcc greatest2.c -o greatest2
# !./greatest2
# Out:
# Enter a, b and c: 79697
# 7
# 45
# 79697 is greatest
# 45 is greater
# 7 is smallest

# %% [markdown]
# Using ternary operator

# %%
# %%writefile greatest2.c
# #include <stdio.h>
#
# int main() {
#     int a, b, c;
#
#     printf("Enter a, b and c: ");
#     scanf("%d %d %d", &a, &b, &c);
#
#     (a==b==c)?
# }

# %% [markdown]
# 8. Write a C program to check whether a number is divisible by 5 and 11.

# %%
# %%writefile divisible.c
# #include <stdio.h>
# int main(){
#   int a;
#   printf("Enter the number: ");
#   scanf("%d", &a);
#   (a%5==0 && a%11==0)? printf("%d is divisible by 5 and 11", a): printf("%d is not divisible by 5 and 11", a);
#   return 0;
# }
# Out:
# Overwriting divisible.c

# %%
# !gcc divisible.c -o divisible
# !./divisible
# Out:
# Enter the number: 605
# 605 is divisible by 5 and 11

# %% [markdown]
# 9. Write a C program  to check whether a given character is an uppercase letter, lowercase letter, digit, or special character.

# %%
# %%writefile letter.c
# #include <stdio.h>
# int main(){
#   char ch;
#   printf("Enter the character: ");
#   scanf("%c", &ch);
#     (ch >= 'A' && ch <= 'Z') ? printf("Uppercase letter") :
#     (ch >= 'a' && ch <= 'z') ? printf("Lowercase letter") :
#     (ch >= '0' && ch <= '9') ? printf("Digit") :
#     printf("Special character");
#   return 0;
# }
# Out:
# Overwriting letter.c

# %%
# !gcc letter.c -o letter
# !./letter
# Out:
# Enter the character: A
# Uppercase letter

# %% [markdown]
# 10. Write a C program to check whether three sides can form a valid triangle.

# %%
# %%writefile triangle.c
# #include <stdio.h>
# int main(){
#   int a, b,c;
#   printf("Enter 3 sides of a triangle");
#   scanf("%d %d %d", &a, &b, &c);
#   (a+b>c && a+c>b && b+c>a)? printf("Its a triangle"): printf("Its not a triangle");
#   return 0;
# }
# Out:
# Writing triangle.c

# %%
# !gcc triangle.c -o triangle
# !./triangle
# Out:
# Enter 3 sides of a triangle

# %% [markdown]
# 11. Write a C program to determine whether a triangle is equilateral, isosceles, or scalene.

# %%
# %%writefile typetri.c
# #include<stdio.h>
# int main(){
#   int a,b,c;
#   printf("Enter the sides of a triangle");
#   scanf("%d %d %d", &a, &b, &c);
#   if (a==b && b==c){
#     printf("Its an equilateral triangle");
#   }
#   else if (a==b || b==c || c==a) {
#     printf("Its an isoceles triangle");
#   }
#   else {
#     printf("Its a scalene triangle");
#   }
#   return 0;
# }
# Out:
# Overwriting typetri.c

# %%
# !gcc typetri.c -o typetri
# !./typetri
# Out:
# Enter the sides of a triangle4
# 4
# 7
# Its an isoceles triangle

# %% [markdown]
# 12. WAP to find right angle triangle or not.

# %%
# %%writefile rightangle.c
# #include <stdio.h>
# #include <math.h>
# int main(){
#   int a, b, c;
#   printf("Enter the sides");
#   scanf("%d %d %d", &a,&b,&c);
#
#  (pow(a,2)+pow(b,2)==pow(c,2) || pow(b,2)+pow(c,2)==pow(a,2) || pow(a,2)+pow(c,2)==pow(b,2))? printf("Its a right angle triangle"): printf("Its not a right angle triangle");
#  return 0;
# }
# Out:
# Writing rightangle.c

# %%
# !gcc rightangle.c -o rightangle -lm
# !./rightangle
# Out:
# Enter the sides3
# 4
# 5
# Its a right angle triangle

# %% [markdown]
# 13. Write a C program to calculate grade based on marks:
#
# 90–100 → A
# 80–89 → B
# 70–79 → C
# 60–69 → D
# Below 60 → F

# %%
# %%writefile grade.c
# #include <stdio.h>
# int main(){
#   int grade;
#   printf("Enter marks: ");
#   scanf("%d", &grade);
#   if (grade>=90 && grade<=100){
#           printf("A");
#   }
#   else if (grade >=80 && grade<=89){
#           printf("B");
#   }
#   else if (grade >=70 && grade <=79){
#           printf("C");
#   }
#   else if (grade >=60 && grade<=69){
#            printf("D");
#   }
#   else {
#         printf("F");
#   }
#   return 0;
# }
# Out:
# Overwriting grade.c

# %%
# !gcc grade.c -o grade -lm
# !./grade
# Out:
# Enter marks: 76
# C

# %% [markdown]
# # **Challenge**

# %% [markdown]
# 14. Write a C program to calculate an electricity bill based on units consumed.
#
# First 100 units → $2 per unit
# Next 100 units → $3 per unit
# Above 200 units → $5 per unit

# %%
# %%writefile unit.c
# #include <stdio.h>
# int main(){
#   int unit, cost;
#   printf("Enter units consumed : ");
#   scanf("%d", &unit);
#   if (unit>=0 && unit<=100){
#     cost=2*unit;
#   }
#   if (unit>=100 && unit <=200){
#     cost=(2*100)+(unit-100)*3;
#   }
#   if (unit>=200){
#     cost=(2*100)+(3*100)+(unit-200)*5;
#   }
#   printf("The total cost is: %d", cost);
#   return 0;
# }
# Out:
# Overwriting unit.c

# %%
# !gcc unit.c -o unit -lm
# !./unit
# Out:
# Enter units consumed : 101
# The total cost is: 203

# %% [markdown]
# 15. Write a C program to calculate the roots of a quadratic equation using if-else.

# %%
# %%writefile quadriatic.c
# #include <stdio.h>
# #include <math.h>
# int main(){
#   int x1, x2, b, a,c, D;
#   printf("Enter a, b and c: ");
#     scanf("%lf %lf %lf", &a, &b, &c);
#
#   D=b**b-4a*c;
#   if (D==0){
#     printf("Only 1 root");
#     x1=x2= -b/(2*a);
#   }
#   else if (D>0){
#     printf("2 real roots");
#     x1=(-b+sqrt(D))/(2*a);
#     x2=(-b-sqrt(D))/(2*a);
#   }
#   else if{
#     printf("No real roots");
#   }
#   return 0;
# }
# Out:
# Writing quadriatic.c

# %%
# !gcc quadriatic.c -o quadriatic -lm
# !./quadriatric

# %% [markdown]
# # **Loops: for, while, do while**

# %% [markdown]
# 1. Find the sum of the first N natural numbers.

# %%
# %%writefile loop1.c
# #include <stdio.h>
# int main(){
#   int N;
#   printf("enter N: ");
#   scanf("%d", &N);
#   int i;
#   for (i=0; i<N; i++){
#     printf("%d\n", i);
#
#   }
#   return 0;
# }
# Out:
# Overwriting loop1.c

# %%
# !gcc loop1.c -o loop1
# !./loop1
# Out:
# enter N: ^C

# %% [markdown]
# 2. Find the factorial of a number.

# %%
# %%writefile loop2.c
# #include<stdio.h>
# int main(){
#   int fact=1;
#   int n, i;
#   printf("Enter the number: ");
#   scanf("%d", &n);
#   if (n==0){
#     fact=1;
#     printf("factorial of the number %d is %d ", n, fact );
#   }
#   else{
#      for (i=1; i<=n; i++){
#       fact=fact*i;
#      }
#      printf("factorial of the number %d is %d ", n, fact);
#   }
#   return 0;
# }
# Out:
# Overwriting loop2.c

# %%
# !gcc loop2.c -o loop2
# !./loop2
# Out:
# Enter the number: 0
# factorial of the number 0 is 1

# %% [markdown]
# 3. Print the multiplication table of a number.

# %%
# %%writefile loop3.c
# #include<stdio.h>
# int main(){
#   int fact;
#   int n, i;
#   printf("Enter the number: ");
#   scanf("%d", &n);
#   printf("Multiplication Table: \n");
#   for (i=1; i<=12; i++){
#     printf("%d x %d = %d \n", n,i, i*n);
#       }
#       return 0;
# }
# Out:
# Overwriting loop3.c

# %%
# !gcc loop3.c -o loop3
# !./loop3
# Out:
# Enter the number: 7
# Multiplication Table:
# 7 x 1 = 7
# 7 x 2 = 14
# 7 x 3 = 21
# 7 x 4 = 28
# 7 x 5 = 35
# 7 x 6 = 42
# 7 x 7 = 49
# 7 x 8 = 56
# 7 x 9 = 63
# 7 x 10 = 70
# 7 x 11 = 77
# 7 x 12 = 84

# %% [markdown]
# 4. Reverse a number.

# %%
# %%writefile loop4.c
# #include <stdio.h>
# int main(){
#   int n, copy , rev=0;
#   printf("Enter the number: ");
#   scanf("%d", &n);
#   copy=n;
#   while (n>0){
#            rev = rev * 10 + (n % 10);
#            n/=10;
#   }
#   printf(" The reverse of this number %d is %d ", copy, rev);
#   return 0;
# }
# Out:
# Overwriting loop4.c

# %%
# !gcc loop4.c -o loop4
# !./loop4
# Out:
# Enter the number: 68485839
#  The reverse of this number 68485839 is 93858486

# %% [markdown]
# 9. Palindrome or not.

# %%
# %%writefile loop9.c
# #include <stdio.h>
# int main(){
#   int n, copy , rev=0;
#   printf("Enter the number: ");
#   scanf("%d", &n);
#   copy=n;
#   while (n>0){
#            rev = rev * 10 + (n % 10);
#            n/=10;
#   }
#   if (copy==rev)
#     printf("Yes its a palindrome number");
#   else
#     printf("Its not a palindrome number");
#
#
#   return 0;
# }
# Out:
# Writing loop9.c

# %%
# !gcc loop9.c -o loop9
# !./loop9
# Out:
# Enter the number: 7860
# Its not a palindrome number

# %% [markdown]
# 5. Count number of digits in a number.

# %%
# %%writefile loop5.c
# #include <stdio.h>
# int main(){
#   int n, copy;
#   int count=0;
#   printf("Enter the number: ");
#   scanf("%d" , &n);
#   copy=n;
#   while (n>0){
#     n/=10;
#     count+=1;
#   }
#   printf("The number of digits in %d is %d" , copy, count);
#   return 0;
# }
# Out:
# Writing loop5.c

# %%
# !gcc loop5.c -o loop5
# !./loop5
# Out:
# Enter the number: 5678
# The number of digits in 5678 is 4

# %% [markdown]
# 6. Print all prime numbers between 1 and N.

# %%
# %%writefile loop6.c

# %% [markdown]
# 7. Print all even numbers from 1 to N.

# %% [markdown]
# 8. Print the Fibonacci series up to N terms.
